# %%
! wget https://www.gutenberg.org/files/4300/4300-0.txt 

f = open("4300-0.txt", "r",encoding="utf-8-sig")
ulyses=f.read()
f.close()

! wget http://www.gutenberg.org/files/76/76-0.txt

f = open("76-0.txt", "r",encoding="utf-8-sig")
huck=f.read()
f.close()

! wget http://www.gutenberg.org/files/205/205-0.txt
f = open("205-0.txt", "r",encoding="utf-8-sig")
civil=f.read()
f.close()    
    

! wget http://www.gutenberg.org/files/203/203-0.txt
f = open("203-0.txt", "r",encoding="utf-8-sig")
tomcabin=f.read()
f.close()    
    

! wget http://www.gutenberg.org/files/2852/2852-0.txt
f = open("2852-0.txt", "r",encoding="utf-8-sig")
baskerville=f.read()
f.close()    
    

! wget http://www.gutenberg.org/cache/epub/45631/pg45631.txt
f = open("pg45631.txt", "r",encoding="utf-8-sig")
twelveyears=f.read()
f.close()   

! wget http://www.gutenberg.org/cache/epub/8387/pg8387.txt
f = open("pg8387.txt", "r",encoding="utf-8-sig")
hunger=f.read()
f.close()    
    

! wget http://www.gutenberg.org/files/215/215-0.txt

f = open("215-0.txt", "r",encoding="utf-8-sig")
hunger=f.read()
f.close()    
    

lib = [ baskerville ,
        civil       ,  
        huck        ,  
        hunger      ,  
        tomcabin    ,  
        twelveyears ,  
        ulyses      ,    
      ]

len(lib)

import pickle

import pickle
with open('library.pkl', 'wb') as fh:
    pickle.dump(lib, fh)
# Out:
# --2020-08-07 21:40:34--  https://www.gutenberg.org/files/4300/4300-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1586488 (1.5M) [text/plain]
# Saving to: ‘4300-0.txt.11’
#
# 4300-0.txt.11       100%[===================>]   1.51M  1.53MB/s    in 1.0s
#
# 2020-08-07 21:40:36 (1.53 MB/s) - ‘4300-0.txt.11’ saved [1586488/1586488]
#
# --2020-08-07 21:40:36--  http://www.gutenberg.org/files/76/76-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 616320 (602K) [text/plain]
# Saving to: ‘76-0.txt.4’
#
# 76-0.txt.4          100%[===================>] 601.88K   991KB/s    in 0.6s
#
# ...
